# %% [markdown]
# <a href="https://colab.research.google.com/github/Git-Divyanshi-shukla/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Git-Divyanshi-shukla/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# My lane: Content Performance and Audience Engagement
#
# I want to understand which content characteristics and placement factors are associated with better audience engagement. This is useful because content teams can use these insights to make better decisions about what type of content to publish and where to place it.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# My question is: Which content types and placement positions are associated with higher or lower CTR?
#
# This work can support content and marketing teams when deciding what type of content to publish and where to place it. A wrong recommendation could lead to lower engagement, wasted impressions, and less effective use of content placements. The goal is decision support, not a guarantee of future performance.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Quick look at the starter data

import pandas as pd

url = "https://raw.githubusercontent.com/Git-Divyanshi-shukla/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Number of rows:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 4))
print("Average impressions:", round(df["impressions_90d"].mean(), 2))

df[["content_type", "position_tier", "ctr", "impressions_90d"]].head()
# Out:
# Number of rows: 30000
# Average CTR: 0.5107
# Average impressions: 5200.37
#       content_type position_tier   ctr  impressions_90d
# 0  keyword article      striking  0.76             3803
# 1  keyword article      page_3_5  0.05            15320
# 2  keyword article      page_3_5  0.09            12581
# 3  keyword article        page_1  0.49            11751
# 4  keyword article      page_3_5  0.13            19140

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
# Simple check of the fields used for this research question

print("Rows:", len(df))
print("Columns used:", ["content_type", "position_tier", "ctr"])
print("\nMissing values:")
print(df[["content_type", "position_tier", "ctr"]].isna().sum())
# Out:
# Rows: 30000
# Columns used: ['content_type', 'position_tier', 'ctr']
#
# Missing values:
# content_type     0
# position_tier    0
# ctr              0
# dtype: int64

# %% [markdown]
# This work will be able to describe observed relationships between content characteristics, placement, and CTR. The results should be treated as directional decision-support based on the available data.
#
# This work cannot prove that a particular content type or placement causes higher CTR. It also cannot guarantee future performance or predict changes made by Google or other external systems. The findings should be validated before being used for important decisions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
